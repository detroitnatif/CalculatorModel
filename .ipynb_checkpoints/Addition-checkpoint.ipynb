# %%
# Import PyTorch
import torch
from torch import nn

import os
# Import torchvision 
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision import transforms
# Import matplotlib for visualization
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import DataLoader

# %%
x_train = torch.rand(10000, 2)
y_train = torch.sum(x_train, dim=1).unsqueeze(-1)

print(y_train.shape)


x_test = torch.rand(100, 2)
y_test = torch.sum(x_test, dim=1)
# Out:
# torch.Size([10000, 1])

# %%
class NeuralNet(nn.Module):
    
    def __init__(self):
        super(NeuralNet, self).__init__()
        
        self.ln1 = nn.Linear(in_features=2, out_features=32)
        self.ln2 = nn.Linear(in_features=32, out_features=32)
        self.ln3 = nn.Linear(in_features=32, out_features=1)
        
    def forward(self, x):
        x = self.ln1(x)
#         x = torch.nn.functional.tanh(x)
        x = self.ln2(x)
#         x = torch.nn.functional.tanh(x)
        x = self.ln3(x)
#         x = torch.nn.functional.tanh(x)
        return (x)

# %%
model = NeuralNet()
optimizer = optim.Adam(model.parameters(), lr = .0001)
loss_fn = nn.MSELoss()

# %%
import torch
from torch.utils.data import DataLoader

xtrain_loader = DataLoader(x_train, batch_size=100, num_workers=0)
ytrain_loader = DataLoader(y_train, batch_size=100, num_workers=0)

# %%
for idx in range(100):
    
#     model.train()
#     xB = x_train[idx].unsqueeze(0).float()
    ypred = model(x_train)
#     target = y_train[idx].float()
    target = y_train
    loss = loss_fn(ypred, target)
    print(loss)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
# Out:
# tensor(0.8106, grad_fn=<MseLossBackward0>)
# tensor(0.8006, grad_fn=<MseLossBackward0>)
# tensor(0.7907, grad_fn=<MseLossBackward0>)
# tensor(0.7808, grad_fn=<MseLossBackward0>)
# tensor(0.7710, grad_fn=<MseLossBackward0>)
# tensor(0.7613, grad_fn=<MseLossBackward0>)
# tensor(0.7516, grad_fn=<MseLossBackward0>)
# tensor(0.7421, grad_fn=<MseLossBackward0>)
# tensor(0.7325, grad_fn=<MseLossBackward0>)
# tensor(0.7231, grad_fn=<MseLossBackward0>)
# tensor(0.7137, grad_fn=<MseLossBackward0>)
# tensor(0.7044, grad_fn=<MseLossBackward0>)
# tensor(0.6952, grad_fn=<MseLossBackward0>)
# tensor(0.6861, grad_fn=<MseLossBackward0>)
# tensor(0.6770, grad_fn=<MseLossBackward0>)
# tensor(0.6680, grad_fn=<MseLossBackward0>)
# tensor(0.6591, grad_fn=<MseLossBackward0>)
# tensor(0.6503, grad_fn=<MseLossBackward0>)
# tensor(0.6415, grad_fn=<MseLossBackward0>)
# tensor(0.6328, grad_fn=<MseLossBackward0>)
# tensor(0.6242, grad_fn=<MseLossBackward0>)
# tensor(0.6157, grad_fn=<MseLossBackward0>)
# tensor(0.6073, grad_fn=<MseLossBackward0>)
# tensor(0.5989, grad_fn=<MseLossBackward0>)
# tensor(0.5907, grad_fn=<MseLossBackward0>)
# tensor(0.5825, grad_fn=<MseLossBackward0>)
# tensor(0.5744, grad_fn=<MseLossBackward0>)
# tensor(0.5663, grad_fn=<MseLossBackward0>)
# tensor(0.5584, grad_fn=<MseLossBackward0>)
# tensor(0.5506, grad_fn=<MseLossBackward0>)
# tensor(0.5428, grad_fn=<MseLossBackward0>)
# tensor(0.5351, grad_fn=<MseLossBackward0>)
# tensor(0.5275, grad_fn=<MseLossBackward0>)
# tensor(0.5200, grad_fn=<MseLossBackward0>)
# tensor(0.5125, grad_fn=<MseLossBackward0>)
# tensor(0.5052, grad_fn=<MseLossBackward0>)
# tensor(0.4979, grad_fn=<MseLossBackward0>)
# tensor(0.4907, grad_fn=<MseLossBackward0>)
# tensor(0.4836, grad_fn=<MseLossBackward0>)
# tensor(0.4766, grad_fn=<MseLossBackward0>)
# tensor(0.4697, grad_fn=<MseLossBackward0>)
# tensor(0.4628, grad_fn=<MseLossBackward0>)
# tensor(0.4560, grad_fn=<MseLossBackward0>)
# tensor(0.4493, grad_fn=<MseLossBackward0>)
# tensor(0.4427, grad_fn=<MseLossBackward0>)
# tensor(0.4362, grad_fn=<MseLossBackward0>)
# tensor(0.4298, grad_fn=<MseLossBackward0>)
# tensor(0.4234, grad_fn=<MseLossBackward0>)
# tensor(0.4171, grad_fn=<MseLossBackward0>)
# tensor(0.4109, grad_fn=<MseLossBackward0>)
# tensor(0.4048, grad_fn=<MseLossBackward0>)
# tensor(0.3987, grad_fn=<MseLossBackward0>)
# tensor(0.3928, grad_fn=<MseLossBackward0>)
# tensor(0.3869, grad_fn=<MseLossBackward0>)
# tensor(0.3811, grad_fn=<MseLossBackward0>)
# tensor(0.3754, grad_fn=<MseLossBackward0>)
# tensor(0.3697, grad_fn=<MseLossBackward0>)
# tensor(0.3641, grad_fn=<MseLossBackward0>)
# tensor(0.3586, grad_fn=<MseLossBackward0>)
# tensor(0.3532, grad_fn=<MseLossBackward0>)
# tensor(0.3479, grad_fn=<MseLossBackward0>)
# tensor(0.3426, grad_fn=<MseLossBackward0>)
# tensor(0.3374, grad_fn=<MseLossBackward0>)
# tensor(0.3323, grad_fn=<MseLossBackward0>)
# tensor(0.3272, grad_fn=<MseLossBackward0>)
# tensor(0.3223, grad_fn=<MseLossBackward0>)
# tensor(0.3174, grad_fn=<MseLossBackward0>)
# tensor(0.3125, grad_fn=<MseLossBackward0>)
# tensor(0.3078, grad_fn=<MseLossBackward0>)
# tensor(0.3031, grad_fn=<MseLossBackward0>)
# tensor(0.2985, grad_fn=<MseLossBackward0>)
# tensor(0.2939, grad_fn=<MseLossBackward0>)
# tensor(0.2895, grad_fn=<MseLossBackward0>)
# tensor(0.2850, grad_fn=<MseLossBackward0>)
# tensor(0.2807, grad_fn=<MseLossBackward0>)
# tensor(0.2764, grad_fn=<MseLossBackward0>)
# tensor(0.2722, grad_fn=<MseLossBackward0>)
# tensor(0.2681, grad_fn=<MseLossBackward0>)
# tensor(0.2640, grad_fn=<MseLossBackward0>)
# tensor(0.2600, grad_fn=<MseLossBackward0>)
# tensor(0.2561, grad_fn=<MseLossBackward0>)
# tensor(0.2522, grad_fn=<MseLossBackward0>)
# tensor(0.2484, grad_fn=<MseLossBackward0>)
# tensor(0.2447, grad_fn=<MseLossBackward0>)
# tensor(0.2410, grad_fn=<MseLossBackward0>)
# tensor(0.2374, grad_fn=<MseLossBackward0>)
# tensor(0.2338, grad_fn=<MseLossBackward0>)
# tensor(0.2303, grad_fn=<MseLossBackward0>)
# tensor(0.2269, grad_fn=<MseLossBackward0>)
# tensor(0.2235, grad_fn=<MseLossBackward0>)
# tensor(0.2202, grad_fn=<MseLossBackward0>)
# tensor(0.2170, grad_fn=<MseLossBackward0>)
# tensor(0.2138, grad_fn=<MseLossBackward0>)
# tensor(0.2106, grad_fn=<MseLossBackward0>)
# tensor(0.2076, grad_fn=<MseLossBackward0>)
# tensor(0.2045, grad_fn=<MseLossBackward0>)
# tensor(0.2016, grad_fn=<MseLossBackward0>)
# tensor(0.1987, grad_fn=<MseLossBackward0>)
# tensor(0.1958, grad_fn=<MseLossBackward0>)
# tensor(0.1930, grad_fn=<MseLossBackward0>)

# %%
import numpy as np

for i in range(10):
    model.eval()
    idx = np.random.randint(0, len(x_test))
    xB = x_test[idx].unsqueeze(0)

    yB = y_test[idx].unsqueeze(0)
    logits = model(xB)
    ypred = F.softmax(logits, dim=1)
    print(ypred)
# Out:
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
# torch.Size([1])
# tensor([[1.]], grad_fn=<SoftmaxBackward0>)
